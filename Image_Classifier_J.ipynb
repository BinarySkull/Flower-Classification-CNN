# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories.
#
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'  # for better image viewing

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from PIL import Image
import numpy as np

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])
                                      ])

valid_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])
                                      ])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])
                                      ])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
valid_data = datasets.ImageFolder(valid_dir, transform=train_transforms)
test_data = datasets.ImageFolder(test_dir, transform=test_transforms)


# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=64)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network
# Loading the model
model = models.vgg16(pretrained=True)  # After some googling I found VGG-16 is good and not very complex.
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:04<00:00, 112626294.58it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Here we freeze the parameters to stop backpropagating them so we don't train the pretrained weights and save time.
# to freeze part of the convolutional part of vgg16 model and train the rest
for param in model.parameters():
    param.requires_grad = False
        
#Then we replace the final layer of the vgg16 model by a small set of Sequential layers. 
#Used OrderedDict to preserve the order in which the keys are inserted
from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)),
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.5)), # could use a different droupout probability,but 0.5 usually works well
            ('hidden_layer1', nn.Linear(120, 90)),
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,70)), 
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(70,102)),#output size = 102
            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()
   
# Declare classifier
model.classifier = classifier

# %%
# Convert model to be used on GPU
if torch.cuda.is_available():
    model.cuda()

# %%
# define the criterion and the optimizer to be used for training.
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# %%
# Begin Training Loop!
epochs = 25
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1, epochs))
       
    # Set to training mode
    model.train()
     
    # Loss and Accuracy during epochs
    train_loss = 0.0
    train_acc = 0.0
     
    valid_loss = 0.0
    valid_acc = 0.0
 
    for i, (inputs, labels) in enumerate(trainloader):
 
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
         
        # Clean existing gradients
        optimizer.zero_grad()
         
        # Forward pass 
        outputs = model(inputs)
         
        # Compute loss
        loss = criterion(outputs, labels)
         
        # Backpropagate the gradients
        loss.backward()
         
        # Update the parameters
        optimizer.step()
         
        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
         
        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
         
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
        train_acc += acc.item() * inputs.size(0)
         
        print("Counter: {}, Loss on training: {:.4f}, Accuracy: {:.4f}".format(i,loss.item(), acc.item()))
# Out:
# Epoch: 1/25
# Counter: 0, Loss on training: 4.6321, Accuracy: 0.0156
# Counter: 1, Loss on training: 4.6244, Accuracy: 0.0312
# Counter: 2, Loss on training: 4.6337, Accuracy: 0.0156
# Counter: 3, Loss on training: 4.6682, Accuracy: 0.0312
# Counter: 4, Loss on training: 4.6479, Accuracy: 0.0000
# Counter: 100, Loss on training: 3.1653, Accuracy: 0.2656
# Counter: 101, Loss on training: 3.2719, Accuracy: 0.1406
# Counter: 102, Loss on training: 3.2095, Accuracy: 0.0833
# Epoch: 2/25
# Counter: 0, Loss on training: 3.4149, Accuracy: 0.1875
# Counter: 1, Loss on training: 3.0478, Accuracy: 0.2812
# Counter: 2, Loss on training: 3.1753, Accuracy: 0.2812
# Counter: 3, Loss on training: 2.9187, Accuracy: 0.2969
# Counter: 4, Loss on training: 3.2398, Accuracy: 0.1875
# Counter: 5, Loss on training: 3.2901, Accuracy: 0.1562
# Counter: 6, Loss on training: 3.1097, Accuracy: 0.2500
# Counter: 7, Loss on training: 3.0395, Accuracy: 0.2656
# Counter: 8, Loss on training: 2.6052, Accuracy: 0.3281
# Counter: 9, Loss on training: 3.1250, Accuracy: 0.2969
# Counter: 10, Loss on training: 3.1554, Accuracy: 0.2812
# Counter: 11, Loss on training: 3.4455, Accuracy: 0.1562
# Counter: 12, Loss on training: 2.9952, Accuracy: 0.1719
# Counter: 13, Loss on training: 2.7785, Accuracy: 0.2656
# Counter: 14, Loss on training: 2.9930, Accuracy: 0.2812
# Counter: 15, Loss on training: 3.3615, Accuracy: 0.2344
# Counter: 16, Loss on training: 2.9484, Accuracy: 0.1875
# Counter: 17, Loss on training: 2.7850, Accuracy: 0.3750
# Counter: 18, Loss on training: 3.1721, Accuracy: 0.2344
# Counter: 19, Loss on training: 2.7270, Accuracy: 0.3594
# Counter: 20, Loss on training: 2.9390, Accuracy: 0.2812
# Counter: 21, Loss on training: 2.9278, Accuracy: 0.2656
# Counter: 22, Loss on training: 3.0487, Accuracy: 0.2344
# Counter: 23, Loss on training: 2.6940, Accuracy: 0.3594
# Counter: 24, Loss on training: 2.8589, Accuracy: 0.2656
# Counter: 25, Loss on training: 2.7681, Accuracy: 0.2656
# Counter: 26, Loss on training: 2.8283, Accuracy: 0.2344
# Counter: 27, Loss on training: 3.0419, Accuracy: 0.3750
# Counter: 28, Loss on training: 3.1929, Accuracy: 0.2188
# Counter: 29, Loss on training: 2.8269, Accuracy: 0.2969
# Counter: 30, Loss on training: 2.7061, Accuracy: 0.3594
# Counter: 31, Loss on training: 2.8846, Accuracy: 0.2656
# Counter: 32, Loss on training: 2.8447, Accuracy: 0.2812
# Counter: 33, Loss on training: 2.3031, Accuracy: 0.4062
# Counter: 34, Loss on training: 2.5746, Accuracy: 0.3281
# Counter: 35, Loss on training: 3.0885, Accuracy: 0.2188
# Counter: 36, Loss on training: 2.2705, Accuracy: 0.4219
# Counter: 37, Loss on training: 2.3232, Accuracy: 0.4688
# Counter: 38, Loss on training: 2.9500, Accuracy: 0.2188
# Counter: 39, Loss on training: 2.8704, Accuracy: 0.2969
# Counter: 40, Loss on training: 2.7554, Accuracy: 0.2344
# Counter: 41, Loss on training: 3.0075, Accuracy: 0.2500
# Counter: 42, Loss on training: 2.8374, Accuracy: 0.2500
# Counter: 43, Loss on training: 2.6274, Accuracy: 0.3594
# Counter: 44, Loss on training: 2.6017, Accuracy: 0.3125
# Counter: 45, Loss on training: 2.9716, Accuracy: 0.2500
# Counter: 46, Loss on training: 2.8125, Accuracy: 0.2969
# Counter: 47, Loss on training: 2.7814, Accuracy: 0.2969
# Counter: 48, Loss on training: 2.4999, Accuracy: 0.3438
# Counter: 49, Loss on training: 2.8409, Accuracy: 0.2188
# Counter: 50, Loss on training: 2.8644, Accuracy: 0.3125
# Counter: 51, Loss on training: 2.4419, Accuracy: 0.3594
# Counter: 52, Loss on training: 2.9588, Accuracy: 0.2031
# Counter: 53, Loss on training: 2.7477, Accuracy: 0.3125
# Counter: 54, Loss on training: 2.8248, Accuracy: 0.2031
# Counter: 55, Loss on training: 2.7817, Accuracy: 0.3438
# Counter: 56, Loss on training: 2.6581, Accuracy: 0.3438
# Counter: 57, Loss on training: 2.3998, Accuracy: 0.3750
# Counter: 58, Loss on training: 3.1212, Accuracy: 0.2500
# Counter: 59, Loss on training: 2.5806, Accuracy: 0.3125
# Counter: 60, Loss on training: 2.6014, Accuracy: 0.2656
# Counter: 61, Loss on training: 2.5907, Accuracy: 0.3438
# Counter: 62, Loss on training: 2.9356, Accuracy: 0.2188
# Counter: 63, Loss on training: 2.5419, Accuracy: 0.3594
# Counter: 64, Loss on training: 2.5004, Accuracy: 0.3125
# Counter: 65, Loss on training: 2.6669, Accuracy: 0.2812
# Counter: 66, Loss on training: 2.6084, Accuracy: 0.2656
# Counter: 67, Loss on training: 2.6038, Accuracy: 0.2969
# Counter: 68, Loss on training: 2.6280, Accuracy: 0.3438
# Counter: 69, Loss on training: 2.4881, Accuracy: 0.2812
# Counter: 70, Loss on training: 2.5500, Accuracy: 0.3594
# Counter: 71, Loss on training: 2.5637, Accuracy: 0.3438
# Counter: 72, Loss on training: 2.6394, Accuracy: 0.3125
# Counter: 73, Loss on training: 2.1810, Accuracy: 0.4531
# Counter: 74, Loss on training: 2.5132, Accuracy: 0.3750
# Counter: 75, Loss on training: 2.6096, Accuracy: 0.2812
# Counter: 76, Loss on training: 2.6361, Accuracy: 0.3281
# Counter: 77, Loss on training: 2.9389, Accuracy: 0.2500
# Counter: 78, Loss on training: 2.6169, Accuracy: 0.3125
# Counter: 79, Loss on training: 2.4271, Accuracy: 0.4062
# Counter: 80, Loss on training: 2.8272, Accuracy: 0.2188
# Counter: 81, Loss on training: 2.3571, Accuracy: 0.3906
# Counter: 82, Loss on training: 2.5340, Accuracy: 0.2969
# Counter: 83, Loss on training: 2.6187, Accuracy: 0.2812
# Counter: 84, Loss on training: 2.3505, Accuracy: 0.3750
# Counter: 85, Loss on training: 2.1372, Accuracy: 0.3906
# Counter: 86, Loss on training: 2.5124, Accuracy: 0.3594
# Counter: 87, Loss on training: 2.3428, Accuracy: 0.3438
# Counter: 88, Loss on training: 2.0838, Accuracy: 0.4688
# Counter: 89, Loss on training: 2.5063, Accuracy: 0.4375
# Counter: 90, Loss on training: 2.3717, Accuracy: 0.3594
# Counter: 91, Loss on training: 2.1701, Accuracy: 0.4844
# Counter: 92, Loss on training: 2.8095, Accuracy: 0.2500
# Counter: 93, Loss on training: 2.2530, Accuracy: 0.3281
# Counter: 94, Loss on training: 2.6531, Accuracy: 0.3438
# Counter: 95, Loss on training: 2.4799, Accuracy: 0.3281
# Counter: 96, Loss on training: 2.2729, Accuracy: 0.3281
# Counter: 97, Loss on training: 2.5663, Accuracy: 0.2656
# Counter: 98, Loss on training: 2.3481, Accuracy: 0.2656
# Counter: 99, Loss on training: 2.7341, Accuracy: 0.3125
# Counter: 100, Loss on training: 2.4232, Accuracy: 0.3438
# Counter: 101, Loss on training: 2.5533, Accuracy: 0.3594
# Counter: 102, Loss on training: 2.2171, Accuracy: 0.2500
# Epoch: 3/25
# Counter: 0, Loss on training: 2.2528, Accuracy: 0.3594
# Counter: 1, Loss on training: 2.3663, Accuracy: 0.4062
# Counter: 2, Loss on training: 2.7986, Accuracy: 0.2500
# Counter: 3, Loss on training: 2.7545, Accuracy: 0.2969
# Counter: 4, Loss on training: 2.5061, Accuracy: 0.3750
# Counter: 5, Loss on training: 2.2254, Accuracy: 0.4531
# Counter: 6, Loss on training: 2.4313, Accuracy: 0.3594
# Counter: 7, Loss on training: 2.6080, Accuracy: 0.3438
# Counter: 8, Loss on training: 2.3172, Accuracy: 0.4375
# Counter: 9, Loss on training: 2.5050, Accuracy: 0.3438
# Counter: 10, Loss on training: 2.3057, Accuracy: 0.4531
# Counter: 11, Loss on training: 2.4714, Accuracy: 0.3594
# Counter: 12, Loss on training: 2.8414, Accuracy: 0.2969
# Counter: 13, Loss on training: 2.3943, Accuracy: 0.2969
# Counter: 14, Loss on training: 2.2871, Accuracy: 0.3594
# Counter: 15, Loss on training: 2.2794, Accuracy: 0.3594
# Counter: 16, Loss on training: 2.5528, Accuracy: 0.3906
# Counter: 17, Loss on training: 2.4949, Accuracy: 0.3906
# Counter: 18, Loss on training: 2.5921, Accuracy: 0.2812
# Counter: 19, Loss on training: 2.5315, Accuracy: 0.2812
# Counter: 20, Loss on training: 2.3442, Accuracy: 0.4062
# Counter: 21, Loss on training: 2.7703, Accuracy: 0.2500
# Counter: 22, Loss on training: 2.2847, Accuracy: 0.3906
# Counter: 23, Loss on training: 2.4758, Accuracy: 0.2969
# Counter: 24, Loss on training: 1.9564, Accuracy: 0.4219
# Counter: 25, Loss on training: 2.2914, Accuracy: 0.3750
# Counter: 26, Loss on training: 2.4142, Accuracy: 0.4219
# Counter: 27, Loss on training: 1.9909, Accuracy: 0.3750
# Counter: 28, Loss on training: 2.3946, Accuracy: 0.4375
# Counter: 29, Loss on training: 2.5567, Accuracy: 0.3281
# Counter: 30, Loss on training: 2.3084, Accuracy: 0.3906
# Counter: 31, Loss on training: 2.3865, Accuracy: 0.4219
# Counter: 32, Loss on training: 2.2163, Accuracy: 0.4531
# Counter: 33, Loss on training: 2.0679, Accuracy: 0.4219
# Counter: 34, Loss on training: 2.4048, Accuracy: 0.2812
# Counter: 73, Loss on training: 2.3178, Accuracy: 0.4062
# Counter: 74, Loss on training: 2.5437, Accuracy: 0.3125
# Counter: 75, Loss on training: 1.9237, Accuracy: 0.3906
# Counter: 76, Loss on training: 2.1696, Accuracy: 0.4219
# Counter: 77, Loss on training: 1.9668, Accuracy: 0.5312
# Counter: 78, Loss on training: 2.0042, Accuracy: 0.4219
# Counter: 79, Loss on training: 1.9734, Accuracy: 0.4219
# Counter: 80, Loss on training: 2.1647, Accuracy: 0.3750
# Counter: 81, Loss on training: 1.8383, Accuracy: 0.5000
# Counter: 82, Loss on training: 1.6897, Accuracy: 0.5625
# Counter: 83, Loss on training: 1.7503, Accuracy: 0.5000
# Counter: 84, Loss on training: 1.8420, Accuracy: 0.4531
# Counter: 85, Loss on training: 2.4310, Accuracy: 0.3594
# Counter: 86, Loss on training: 1.9229, Accuracy: 0.4219
# Counter: 87, Loss on training: 1.7907, Accuracy: 0.5312
# Counter: 88, Loss on training: 1.9009, Accuracy: 0.4531
# Counter: 89, Loss on training: 2.2260, Accuracy: 0.5000
# Counter: 90, Loss on training: 1.7468, Accuracy: 0.4844
# Counter: 91, Loss on training: 1.8005, Accuracy: 0.4844
# Counter: 92, Loss on training: 2.3454, Accuracy: 0.5000
# Counter: 93, Loss on training: 2.6036, Accuracy: 0.3750
# Counter: 94, Loss on training: 1.9377, Accuracy: 0.4844
# Counter: 95, Loss on training: 2.1204, Accuracy: 0.5781
# Counter: 96, Loss on training: 1.7585, Accuracy: 0.5156
# Counter: 97, Loss on training: 2.1066, Accuracy: 0.4531
# Counter: 98, Loss on training: 1.9688, Accuracy: 0.4531
# Counter: 99, Loss on training: 2.0693, Accuracy: 0.4375
# Counter: 100, Loss on training: 2.0356, Accuracy: 0.4219
# Counter: 101, Loss on training: 1.7896, Accuracy: 0.5469
# Counter: 102, Loss on training: 1.6071, Accuracy: 0.5000
# Epoch: 5/25
# Counter: 0, Loss on training: 1.6531, Accuracy: 0.5938
# Counter: 1, Loss on training: 2.0572, Accuracy: 0.4375
# Counter: 2, Loss on training: 2.1179, Accuracy: 0.4531
# Counter: 3, Loss on training: 1.7505, Accuracy: 0.4531
# Counter: 4, Loss on training: 1.6961, Accuracy: 0.5625
# Counter: 5, Loss on training: 1.8884, Accuracy: 0.4844
# Counter: 6, Loss on training: 1.8203, Accuracy: 0.4688
# Counter: 7, Loss on training: 2.0764, Accuracy: 0.4531
# Counter: 8, Loss on training: 1.7750, Accuracy: 0.4688
# Counter: 9, Loss on training: 2.0046, Accuracy: 0.4062
# Counter: 10, Loss on training: 1.9464, Accuracy: 0.4688
# Counter: 11, Loss on training: 2.0107, Accuracy: 0.5000
# Counter: 12, Loss on training: 2.2397, Accuracy: 0.3594
# Counter: 13, Loss on training: 2.2232, Accuracy: 0.3281
# Counter: 14, Loss on training: 2.0417, Accuracy: 0.4531
# Counter: 15, Loss on training: 2.2556, Accuracy: 0.3750
# Counter: 16, Loss on training: 1.9094, Accuracy: 0.4062
# Counter: 55, Loss on training: 1.6509, Accuracy: 0.5312
# Counter: 56, Loss on training: 1.6610, Accuracy: 0.5000
# Counter: 57, Loss on training: 1.4810, Accuracy: 0.5625
# Counter: 58, Loss on training: 2.0673, Accuracy: 0.4844
# Counter: 59, Loss on training: 1.6032, Accuracy: 0.5000
# Counter: 60, Loss on training: 1.5254, Accuracy: 0.5625
# Counter: 61, Loss on training: 1.7027, Accuracy: 0.5781
# Counter: 62, Loss on training: 1.6267, Accuracy: 0.5469
# Counter: 63, Loss on training: 2.0162, Accuracy: 0.4375
# Counter: 64, Loss on training: 1.5926, Accuracy: 0.5469
# Counter: 65, Loss on training: 1.6443, Accuracy: 0.5000
# Counter: 66, Loss on training: 2.0350, Accuracy: 0.5469
# Counter: 67, Loss on training: 2.1080, Accuracy: 0.4531
# Counter: 68, Loss on training: 2.3548, Accuracy: 0.3906
# Counter: 69, Loss on training: 2.2314, Accuracy: 0.4062
# Counter: 70, Loss on training: 1.8171, Accuracy: 0.5312
# Counter: 71, Loss on training: 1.7064, Accuracy: 0.5156
# Counter: 72, Loss on training: 1.9724, Accuracy: 0.4531
# Counter: 73, Loss on training: 1.5035, Accuracy: 0.5625
# Counter: 74, Loss on training: 2.2161, Accuracy: 0.4688
# Counter: 75, Loss on training: 1.7076, Accuracy: 0.5312
# Counter: 76, Loss on training: 1.3955, Accuracy: 0.5312
# Counter: 77, Loss on training: 1.5905, Accuracy: 0.5469
# Counter: 78, Loss on training: 1.3844, Accuracy: 0.5781
# Counter: 79, Loss on training: 1.7746, Accuracy: 0.5000
# Counter: 80, Loss on training: 1.6594, Accuracy: 0.4688
# Counter: 81, Loss on training: 2.0411, Accuracy: 0.4062
# Counter: 82, Loss on training: 1.6506, Accuracy: 0.5938
# Counter: 83, Loss on training: 1.6171, Accuracy: 0.5156
# Counter: 84, Loss on training: 2.1945, Accuracy: 0.4375
# Counter: 85, Loss on training: 1.6575, Accuracy: 0.5781
# Counter: 86, Loss on training: 1.7748, Accuracy: 0.5469
# Counter: 87, Loss on training: 1.8700, Accuracy: 0.4844
# Counter: 88, Loss on training: 2.2444, Accuracy: 0.2969
# Counter: 89, Loss on training: 2.0961, Accuracy: 0.4219
# Counter: 90, Loss on training: 1.8084, Accuracy: 0.5000
# Counter: 91, Loss on training: 1.8201, Accuracy: 0.4844
# Counter: 92, Loss on training: 2.2185, Accuracy: 0.5469
# Counter: 93, Loss on training: 2.0394, Accuracy: 0.4062
# Counter: 94, Loss on training: 1.7650, Accuracy: 0.4844
# Counter: 95, Loss on training: 2.0313, Accuracy: 0.3594
# Counter: 96, Loss on training: 1.5013, Accuracy: 0.5625
# Counter: 97, Loss on training: 1.3940, Accuracy: 0.6406
# Counter: 98, Loss on training: 1.7712, Accuracy: 0.5469
# Counter: 99, Loss on training: 2.0304, Accuracy: 0.4062
# Counter: 100, Loss on training: 1.8406, Accuracy: 0.4531
# Counter: 101, Loss on training: 1.6039, Accuracy: 0.5781
# Counter: 102, Loss on training: 1.4700, Accuracy: 0.6250
# Epoch: 7/25
# Counter: 0, Loss on training: 1.6248, Accuracy: 0.5781
# Counter: 1, Loss on training: 1.7778, Accuracy: 0.5000
# Counter: 2, Loss on training: 1.4245, Accuracy: 0.5938
# Counter: 3, Loss on training: 1.6246, Accuracy: 0.5156
# Counter: 4, Loss on training: 2.0428, Accuracy: 0.4531
# Counter: 5, Loss on training: 1.8860, Accuracy: 0.4844
# Counter: 6, Loss on training: 1.4846, Accuracy: 0.5781
# Counter: 7, Loss on training: 1.6923, Accuracy: 0.5312
# Counter: 8, Loss on training: 1.8819, Accuracy: 0.4531
# Counter: 9, Loss on training: 2.2602, Accuracy: 0.4531
# Counter: 10, Loss on training: 1.5422, Accuracy: 0.6094
# Counter: 11, Loss on training: 1.8037, Accuracy: 0.4688
# Counter: 12, Loss on training: 1.6392, Accuracy: 0.5469
# Counter: 13, Loss on training: 1.6288, Accuracy: 0.5312
# Counter: 14, Loss on training: 1.5444, Accuracy: 0.6094
# Counter: 15, Loss on training: 1.8728, Accuracy: 0.5000
# Counter: 16, Loss on training: 1.4332, Accuracy: 0.6719
# Counter: 17, Loss on training: 1.9790, Accuracy: 0.4844
# Counter: 18, Loss on training: 1.8036, Accuracy: 0.5000
# Counter: 19, Loss on training: 2.0987, Accuracy: 0.4219
# Counter: 20, Loss on training: 1.4263, Accuracy: 0.5781
# Counter: 21, Loss on training: 2.0281, Accuracy: 0.4844
# Counter: 22, Loss on training: 1.7681, Accuracy: 0.4688
# Counter: 23, Loss on training: 2.0107, Accuracy: 0.4688
# Counter: 24, Loss on training: 1.8814, Accuracy: 0.5312
# Counter: 25, Loss on training: 1.7585, Accuracy: 0.5156
# Counter: 26, Loss on training: 1.6171, Accuracy: 0.5000
# Counter: 27, Loss on training: 1.6317, Accuracy: 0.5312
# Counter: 28, Loss on training: 1.7019, Accuracy: 0.5312
# Counter: 29, Loss on training: 2.0210, Accuracy: 0.4375
# Counter: 30, Loss on training: 1.4093, Accuracy: 0.6562
# Counter: 31, Loss on training: 2.2883, Accuracy: 0.4219
# Counter: 32, Loss on training: 1.5465, Accuracy: 0.6250
# Counter: 33, Loss on training: 1.6577, Accuracy: 0.5156
# Counter: 34, Loss on training: 1.7148, Accuracy: 0.5156
# Counter: 35, Loss on training: 2.0947, Accuracy: 0.4062
# Counter: 36, Loss on training: 1.9231, Accuracy: 0.4688
# Counter: 37, Loss on training: 1.8527, Accuracy: 0.5000
# Counter: 38, Loss on training: 1.7324, Accuracy: 0.5312
# Counter: 39, Loss on training: 1.5065, Accuracy: 0.5938
# Counter: 40, Loss on training: 1.9315, Accuracy: 0.5312
# Counter: 41, Loss on training: 1.8746, Accuracy: 0.4688
# Counter: 42, Loss on training: 2.1362, Accuracy: 0.4844
# Counter: 43, Loss on training: 2.0787, Accuracy: 0.3750
# Counter: 44, Loss on training: 1.8882, Accuracy: 0.4688
# Counter: 45, Loss on training: 1.6367, Accuracy: 0.6250
# Counter: 46, Loss on training: 1.6655, Accuracy: 0.5938
# Counter: 47, Loss on training: 1.7841, Accuracy: 0.5625
# Counter: 48, Loss on training: 1.6469, Accuracy: 0.4688
# Counter: 49, Loss on training: 1.9814, Accuracy: 0.4219
# Counter: 50, Loss on training: 1.7009, Accuracy: 0.5625
# Counter: 51, Loss on training: 1.8752, Accuracy: 0.5312
# Counter: 52, Loss on training: 1.7792, Accuracy: 0.4375
# Counter: 53, Loss on training: 1.5310, Accuracy: 0.5781
# Counter: 54, Loss on training: 1.7935, Accuracy: 0.5000
# Counter: 55, Loss on training: 1.9980, Accuracy: 0.4219
# Counter: 56, Loss on training: 1.8756, Accuracy: 0.5312
# Counter: 57, Loss on training: 2.0199, Accuracy: 0.4219
# Counter: 58, Loss on training: 1.8937, Accuracy: 0.5469
# Counter: 59, Loss on training: 1.7957, Accuracy: 0.4531
# Counter: 60, Loss on training: 2.0502, Accuracy: 0.4844
# Counter: 61, Loss on training: 1.6694, Accuracy: 0.5312
# Counter: 62, Loss on training: 1.6588, Accuracy: 0.4375
# Counter: 63, Loss on training: 2.0139, Accuracy: 0.4688
# Counter: 64, Loss on training: 1.6784, Accuracy: 0.5000
# Counter: 65, Loss on training: 1.6838, Accuracy: 0.5625
# Counter: 66, Loss on training: 1.8703, Accuracy: 0.4844
# Counter: 67, Loss on training: 1.8718, Accuracy: 0.5469
# Counter: 68, Loss on training: 2.2296, Accuracy: 0.3750
# Counter: 69, Loss on training: 1.9123, Accuracy: 0.5312
# Counter: 70, Loss on training: 1.5135, Accuracy: 0.5625
# Counter: 71, Loss on training: 1.6430, Accuracy: 0.5312
# Counter: 72, Loss on training: 1.3799, Accuracy: 0.5781
# Counter: 73, Loss on training: 1.6844, Accuracy: 0.5156
# Counter: 74, Loss on training: 1.5463, Accuracy: 0.5625
# Counter: 75, Loss on training: 1.8768, Accuracy: 0.5000
# Counter: 76, Loss on training: 1.7468, Accuracy: 0.5625
# Counter: 77, Loss on training: 1.5631, Accuracy: 0.6094
# Counter: 78, Loss on training: 1.6138, Accuracy: 0.5156
# Counter: 79, Loss on training: 2.2875, Accuracy: 0.3906
# Counter: 80, Loss on training: 1.7974, Accuracy: 0.5000
# Counter: 81, Loss on training: 2.1115, Accuracy: 0.5156
# Counter: 82, Loss on training: 1.5981, Accuracy: 0.4844
# Counter: 83, Loss on training: 1.9214, Accuracy: 0.5781
# Counter: 84, Loss on training: 1.7895, Accuracy: 0.5156
# Counter: 85, Loss on training: 1.5211, Accuracy: 0.5156
# Counter: 86, Loss on training: 1.8319, Accuracy: 0.5000
# Counter: 87, Loss on training: 1.8183, Accuracy: 0.4844
# Counter: 88, Loss on training: 1.8638, Accuracy: 0.4688
# Counter: 89, Loss on training: 2.1720, Accuracy: 0.4375
# Counter: 90, Loss on training: 1.6206, Accuracy: 0.6250
# Counter: 91, Loss on training: 1.6944, Accuracy: 0.6250
# Counter: 92, Loss on training: 1.4686, Accuracy: 0.5312
# Counter: 93, Loss on training: 1.5832, Accuracy: 0.4688
# Counter: 94, Loss on training: 1.3096, Accuracy: 0.6406
# Counter: 95, Loss on training: 1.4083, Accuracy: 0.5781
# Counter: 96, Loss on training: 2.0731, Accuracy: 0.3750
# Counter: 97, Loss on training: 1.6321, Accuracy: 0.5781
# Counter: 98, Loss on training: 1.6326, Accuracy: 0.5625
# Counter: 99, Loss on training: 1.4099, Accuracy: 0.5469
# Counter: 100, Loss on training: 1.9115, Accuracy: 0.4375
# Counter: 101, Loss on training: 1.7788, Accuracy: 0.4688
# Counter: 102, Loss on training: 1.5455, Accuracy: 0.6250
# Epoch: 8/25
# Counter: 0, Loss on training: 1.7288, Accuracy: 0.5312
# Counter: 1, Loss on training: 1.4863, Accuracy: 0.6406
# Counter: 2, Loss on training: 1.4567, Accuracy: 0.5938
# Counter: 3, Loss on training: 1.6901, Accuracy: 0.5938
# Counter: 4, Loss on training: 1.1936, Accuracy: 0.7188
# Counter: 5, Loss on training: 1.7826, Accuracy: 0.4688
# Counter: 6, Loss on training: 1.8756, Accuracy: 0.5000
# Counter: 7, Loss on training: 1.8726, Accuracy: 0.4688
# Counter: 8, Loss on training: 1.9434, Accuracy: 0.5156
# Counter: 9, Loss on training: 2.2248, Accuracy: 0.3906
# Counter: 10, Loss on training: 1.8711, Accuracy: 0.5156
# Counter: 11, Loss on training: 1.9643, Accuracy: 0.5000
# Counter: 12, Loss on training: 1.4745, Accuracy: 0.5312
# Counter: 13, Loss on training: 1.7059, Accuracy: 0.4844
# Counter: 14, Loss on training: 1.8284, Accuracy: 0.5156
# Counter: 15, Loss on training: 1.8453, Accuracy: 0.4844
# Counter: 16, Loss on training: 1.6684, Accuracy: 0.5469
# Counter: 17, Loss on training: 1.5702, Accuracy: 0.6094
# Counter: 18, Loss on training: 1.5972, Accuracy: 0.5625
# Counter: 19, Loss on training: 1.9047, Accuracy: 0.5000
# Counter: 20, Loss on training: 1.4708, Accuracy: 0.5625
# Counter: 21, Loss on training: 1.5785, Accuracy: 0.6094
# Counter: 22, Loss on training: 1.9038, Accuracy: 0.5312
# Counter: 23, Loss on training: 1.6539, Accuracy: 0.5781
# Counter: 24, Loss on training: 1.4354, Accuracy: 0.5469
# Counter: 25, Loss on training: 1.7965, Accuracy: 0.4688
# Counter: 26, Loss on training: 1.8375, Accuracy: 0.5312
# Counter: 27, Loss on training: 1.9560, Accuracy: 0.4531
# Counter: 28, Loss on training: 1.9937, Accuracy: 0.5312
# Counter: 29, Loss on training: 2.1399, Accuracy: 0.4219
# Counter: 30, Loss on training: 1.9685, Accuracy: 0.4688
# Counter: 31, Loss on training: 1.7033, Accuracy: 0.5781
# Counter: 32, Loss on training: 1.7572, Accuracy: 0.5156
# Counter: 33, Loss on training: 1.6607, Accuracy: 0.5156
# Counter: 34, Loss on training: 1.6926, Accuracy: 0.5312
# Counter: 35, Loss on training: 2.0270, Accuracy: 0.4688
# Counter: 36, Loss on training: 1.8621, Accuracy: 0.4531
# Counter: 37, Loss on training: 1.6429, Accuracy: 0.6094
# Counter: 38, Loss on training: 1.7213, Accuracy: 0.5312
# Counter: 39, Loss on training: 1.5944, Accuracy: 0.5469
# Counter: 40, Loss on training: 1.7266, Accuracy: 0.5312
# Counter: 41, Loss on training: 1.7249, Accuracy: 0.5625
# Counter: 42, Loss on training: 1.9021, Accuracy: 0.4219
# Counter: 43, Loss on training: 1.7228, Accuracy: 0.5156
# Counter: 44, Loss on training: 1.5750, Accuracy: 0.5781
# Counter: 45, Loss on training: 1.7321, Accuracy: 0.5156
# Counter: 46, Loss on training: 1.3389, Accuracy: 0.5625
# Counter: 47, Loss on training: 1.4509, Accuracy: 0.5938
# Counter: 48, Loss on training: 1.7224, Accuracy: 0.5469
# Counter: 49, Loss on training: 1.7009, Accuracy: 0.5625
# Counter: 50, Loss on training: 2.0220, Accuracy: 0.4531
# Counter: 51, Loss on training: 1.4898, Accuracy: 0.5469
# Counter: 52, Loss on training: 1.7534, Accuracy: 0.5938
# Counter: 53, Loss on training: 1.9443, Accuracy: 0.4219
# Counter: 54, Loss on training: 1.6678, Accuracy: 0.5625
# Counter: 55, Loss on training: 1.8337, Accuracy: 0.4688
# Counter: 56, Loss on training: 1.6484, Accuracy: 0.5469
# Counter: 57, Loss on training: 1.6364, Accuracy: 0.5312
# Counter: 58, Loss on training: 1.4875, Accuracy: 0.5469
# Counter: 59, Loss on training: 1.6019, Accuracy: 0.5625
# Counter: 60, Loss on training: 1.7019, Accuracy: 0.5156
# Counter: 61, Loss on training: 1.3622, Accuracy: 0.6406
# Counter: 62, Loss on training: 1.8228, Accuracy: 0.4531
# Counter: 63, Loss on training: 1.7422, Accuracy: 0.4688
# Counter: 64, Loss on training: 1.5250, Accuracy: 0.4844
# Counter: 65, Loss on training: 1.3805, Accuracy: 0.6406
# Counter: 66, Loss on training: 1.8904, Accuracy: 0.4688
# Counter: 67, Loss on training: 1.5030, Accuracy: 0.6406
# Counter: 68, Loss on training: 2.0214, Accuracy: 0.4219
# Counter: 69, Loss on training: 1.4686, Accuracy: 0.5938
# Counter: 70, Loss on training: 1.7173, Accuracy: 0.5469
# Counter: 71, Loss on training: 1.8049, Accuracy: 0.5312
# Counter: 72, Loss on training: 1.6652, Accuracy: 0.5156
# Counter: 73, Loss on training: 1.9181, Accuracy: 0.4531
# Counter: 74, Loss on training: 1.9063, Accuracy: 0.4844
# Counter: 75, Loss on training: 1.5766, Accuracy: 0.5156
# Counter: 76, Loss on training: 1.6354, Accuracy: 0.5156
# Counter: 77, Loss on training: 1.5882, Accuracy: 0.5938
# Counter: 78, Loss on training: 1.5809, Accuracy: 0.5781
# Counter: 79, Loss on training: 1.9595, Accuracy: 0.4688
# Counter: 80, Loss on training: 1.1608, Accuracy: 0.7188
# Counter: 81, Loss on training: 1.7084, Accuracy: 0.5625
# Counter: 82, Loss on training: 1.7779, Accuracy: 0.4844
# Counter: 83, Loss on training: 1.3678, Accuracy: 0.5938
# Counter: 84, Loss on training: 1.3539, Accuracy: 0.6250
# Counter: 85, Loss on training: 1.3529, Accuracy: 0.6406
# Counter: 86, Loss on training: 1.6302, Accuracy: 0.5938
# Counter: 87, Loss on training: 1.7411, Accuracy: 0.5938
# Counter: 88, Loss on training: 1.6473, Accuracy: 0.5625
# Counter: 89, Loss on training: 1.8208, Accuracy: 0.4844
# Counter: 90, Loss on training: 2.2067, Accuracy: 0.4375
# Counter: 91, Loss on training: 1.4245, Accuracy: 0.5469
# Counter: 92, Loss on training: 1.5289, Accuracy: 0.5938
# Counter: 93, Loss on training: 1.6121, Accuracy: 0.6094
# Counter: 94, Loss on training: 1.9296, Accuracy: 0.4375
# Counter: 95, Loss on training: 1.0708, Accuracy: 0.7188
# Counter: 96, Loss on training: 1.3332, Accuracy: 0.6406
# Counter: 97, Loss on training: 1.6230, Accuracy: 0.5156
# Counter: 98, Loss on training: 1.8935, Accuracy: 0.5000
# Counter: 99, Loss on training: 2.0404, Accuracy: 0.5312
# Counter: 100, Loss on training: 1.9794, Accuracy: 0.5469
# Counter: 101, Loss on training: 1.7447, Accuracy: 0.5000
# Counter: 102, Loss on training: 2.1993, Accuracy: 0.4167
# Epoch: 9/25
# Counter: 0, Loss on training: 1.8738, Accuracy: 0.4375
# Counter: 1, Loss on training: 1.5534, Accuracy: 0.5781
# Counter: 2, Loss on training: 2.0380, Accuracy: 0.4062
# Counter: 3, Loss on training: 1.6013, Accuracy: 0.5469
# Counter: 4, Loss on training: 1.5292, Accuracy: 0.5938
# Counter: 5, Loss on training: 1.1105, Accuracy: 0.7031
# Counter: 6, Loss on training: 1.9176, Accuracy: 0.4844
# Counter: 7, Loss on training: 1.8245, Accuracy: 0.5156
# Counter: 8, Loss on training: 1.6538, Accuracy: 0.5312
# Counter: 9, Loss on training: 1.8468, Accuracy: 0.5312
# Counter: 10, Loss on training: 1.1445, Accuracy: 0.6250
# Counter: 11, Loss on training: 1.7884, Accuracy: 0.5156
# Counter: 12, Loss on training: 1.1714, Accuracy: 0.7188
# Counter: 13, Loss on training: 1.5784, Accuracy: 0.5156
# Counter: 14, Loss on training: 1.6265, Accuracy: 0.5312
# Counter: 15, Loss on training: 1.4547, Accuracy: 0.5312
# Counter: 16, Loss on training: 1.4977, Accuracy: 0.5312
# Counter: 17, Loss on training: 1.8961, Accuracy: 0.5156
# Counter: 18, Loss on training: 1.6652, Accuracy: 0.4531
# Counter: 19, Loss on training: 1.8673, Accuracy: 0.4375
# Counter: 20, Loss on training: 1.4472, Accuracy: 0.5938
# Counter: 21, Loss on training: 1.4906, Accuracy: 0.5625
# Counter: 22, Loss on training: 1.6480, Accuracy: 0.5625
# Counter: 23, Loss on training: 1.3433, Accuracy: 0.6406
# Counter: 24, Loss on training: 1.7835, Accuracy: 0.5156
# Counter: 25, Loss on training: 1.5946, Accuracy: 0.5312
# Counter: 26, Loss on training: 1.6554, Accuracy: 0.5469
# Counter: 27, Loss on training: 1.3457, Accuracy: 0.7031
# Counter: 28, Loss on training: 1.7400, Accuracy: 0.5156
# Counter: 29, Loss on training: 1.4912, Accuracy: 0.5781
# Counter: 30, Loss on training: 1.7078, Accuracy: 0.5469
# Counter: 31, Loss on training: 1.7907, Accuracy: 0.5312
# ...
# Counter: 24, Loss on training: 1.2158, Accuracy: 0.5938
# Counter: 25, Loss on training: 1.1929, Accuracy: 0.7031
# Counter: 26, Loss on training: 1.4646, Accuracy: 0.5938
# Counter: 27, Loss on training: 1.5887, Accuracy: 0.5156
# Counter: 28, Loss on training: 1.5187, Accuracy: 0.5469
# Counter: 29, Loss on training: 1.4238, Accuracy: 0.5625
# Counter: 30, Loss on training: 1.2860, Accuracy: 0.6406
# Counter: 31, Loss on training: 1.1972, Accuracy: 0.6094
# Counter: 32, Loss on training: 1.4082, Accuracy: 0.6406
# Counter: 33, Loss on training: 1.6064, Accuracy: 0.5625
# Counter: 34, Loss on training: 1.0706, Accuracy: 0.7188
# Counter: 35, Loss on training: 1.0201, Accuracy: 0.6562
# Counter: 36, Loss on training: 1.1133, Accuracy: 0.7031
# Counter: 37, Loss on training: 1.5063, Accuracy: 0.5625
# Counter: 38, Loss on training: 1.3630, Accuracy: 0.5781
# Counter: 39, Loss on training: 1.1002, Accuracy: 0.6719
# Counter: 40, Loss on training: 1.4502, Accuracy: 0.5625
# Counter: 41, Loss on training: 1.5551, Accuracy: 0.5625
# Counter: 42, Loss on training: 1.3131, Accuracy: 0.6562
# Counter: 43, Loss on training: 1.3138, Accuracy: 0.5938
# Counter: 44, Loss on training: 1.4047, Accuracy: 0.5781
# Counter: 45, Loss on training: 1.4305, Accuracy: 0.5781
# Counter: 46, Loss on training: 1.1608, Accuracy: 0.6562
# Counter: 47, Loss on training: 1.3695, Accuracy: 0.5781
# Counter: 48, Loss on training: 1.1709, Accuracy: 0.6875
# Counter: 49, Loss on training: 1.2369, Accuracy: 0.6094
# Counter: 50, Loss on training: 1.2578, Accuracy: 0.7031
# Counter: 51, Loss on training: 1.4229, Accuracy: 0.6406
# Counter: 52, Loss on training: 1.1928, Accuracy: 0.7031
# Counter: 53, Loss on training: 1.0742, Accuracy: 0.7344
# Counter: 54, Loss on training: 1.1923, Accuracy: 0.6562
# Counter: 55, Loss on training: 1.1616, Accuracy: 0.6562
# Counter: 56, Loss on training: 1.2913, Accuracy: 0.6406
# Counter: 57, Loss on training: 1.6954, Accuracy: 0.5938
# Counter: 58, Loss on training: 1.3274, Accuracy: 0.6719
# Counter: 59, Loss on training: 1.4657, Accuracy: 0.5938
# Counter: 60, Loss on training: 1.3251, Accuracy: 0.6094
# Counter: 61, Loss on training: 1.2393, Accuracy: 0.5469
# Counter: 62, Loss on training: 1.2471, Accuracy: 0.6406
# Counter: 63, Loss on training: 1.2843, Accuracy: 0.5938
# Counter: 64, Loss on training: 1.2639, Accuracy: 0.6562
# Counter: 65, Loss on training: 1.2411, Accuracy: 0.5781
# Counter: 66, Loss on training: 1.4113, Accuracy: 0.6562
# Counter: 67, Loss on training: 1.0036, Accuracy: 0.6094
# Counter: 68, Loss on training: 1.0649, Accuracy: 0.6406
# Counter: 69, Loss on training: 1.3148, Accuracy: 0.6719
# Counter: 70, Loss on training: 1.4310, Accuracy: 0.6406
# Counter: 71, Loss on training: 1.2246, Accuracy: 0.6719
# Counter: 72, Loss on training: 1.3015, Accuracy: 0.6719
# Counter: 73, Loss on training: 1.1323, Accuracy: 0.6562
# Counter: 74, Loss on training: 1.0393, Accuracy: 0.6562
# Counter: 75, Loss on training: 1.2008, Accuracy: 0.6562
# Counter: 76, Loss on training: 1.2739, Accuracy: 0.6094
# Counter: 77, Loss on training: 1.1676, Accuracy: 0.7031
# Counter: 78, Loss on training: 1.3337, Accuracy: 0.6406
# Counter: 79, Loss on training: 1.4167, Accuracy: 0.5625
# Counter: 80, Loss on training: 1.4092, Accuracy: 0.6719
# Counter: 81, Loss on training: 1.2315, Accuracy: 0.6562
# Counter: 82, Loss on training: 1.4016, Accuracy: 0.5312
# Counter: 83, Loss on training: 1.3044, Accuracy: 0.5938
# Counter: 84, Loss on training: 1.4207, Accuracy: 0.6094
# Counter: 85, Loss on training: 1.1744, Accuracy: 0.6562
# Counter: 86, Loss on training: 1.0076, Accuracy: 0.6562
# Counter: 87, Loss on training: 1.3628, Accuracy: 0.5938
# Counter: 88, Loss on training: 1.2821, Accuracy: 0.6562
# Counter: 89, Loss on training: 1.4459, Accuracy: 0.6719
# Counter: 90, Loss on training: 2.2381, Accuracy: 0.4375
# Counter: 91, Loss on training: 1.1848, Accuracy: 0.7344
# Counter: 92, Loss on training: 1.1699, Accuracy: 0.6719
# Counter: 93, Loss on training: 1.4040, Accuracy: 0.5781
# Counter: 94, Loss on training: 1.4217, Accuracy: 0.6250
# Counter: 95, Loss on training: 1.5786, Accuracy: 0.5938
# Counter: 96, Loss on training: 1.3755, Accuracy: 0.5938
# Counter: 97, Loss on training: 1.4379, Accuracy: 0.5469
# Counter: 98, Loss on training: 1.4085, Accuracy: 0.5781
# Counter: 99, Loss on training: 0.9730, Accuracy: 0.6875
# Counter: 100, Loss on training: 1.2327, Accuracy: 0.6250
# Counter: 101, Loss on training: 1.3595, Accuracy: 0.6094
# Counter: 102, Loss on training: 1.2990, Accuracy: 0.5833
# Epoch: 24/25
# Counter: 0, Loss on training: 1.2014, Accuracy: 0.6406
# Counter: 1, Loss on training: 1.0719, Accuracy: 0.5938
# Counter: 2, Loss on training: 1.4777, Accuracy: 0.5781
# Counter: 3, Loss on training: 1.4636, Accuracy: 0.5781
# Counter: 4, Loss on training: 1.2045, Accuracy: 0.6562
# Counter: 5, Loss on training: 1.2846, Accuracy: 0.6406
# Counter: 6, Loss on training: 1.5715, Accuracy: 0.5781
# Counter: 7, Loss on training: 1.1644, Accuracy: 0.6250
# Counter: 8, Loss on training: 0.9565, Accuracy: 0.7500
# Counter: 9, Loss on training: 1.2520, Accuracy: 0.6562
# Counter: 10, Loss on training: 1.0724, Accuracy: 0.6406
# Counter: 11, Loss on training: 1.1505, Accuracy: 0.6719
# Counter: 12, Loss on training: 1.3004, Accuracy: 0.6250
# Counter: 13, Loss on training: 0.9702, Accuracy: 0.7031
# Counter: 14, Loss on training: 1.3402, Accuracy: 0.6406
# Counter: 15, Loss on training: 1.6346, Accuracy: 0.5469
# Counter: 16, Loss on training: 1.3507, Accuracy: 0.5781
# Counter: 17, Loss on training: 1.2107, Accuracy: 0.6562
# Counter: 18, Loss on training: 1.0689, Accuracy: 0.7656
# Counter: 19, Loss on training: 1.3308, Accuracy: 0.6250
# Counter: 20, Loss on training: 1.4724, Accuracy: 0.6250
# Counter: 21, Loss on training: 1.1439, Accuracy: 0.6250
# Counter: 22, Loss on training: 0.9179, Accuracy: 0.7500
# Counter: 23, Loss on training: 1.3811, Accuracy: 0.6719
# Counter: 24, Loss on training: 1.3474, Accuracy: 0.6406
# Counter: 25, Loss on training: 1.2670, Accuracy: 0.6250
# Counter: 26, Loss on training: 1.3026, Accuracy: 0.6406
# Counter: 27, Loss on training: 1.3362, Accuracy: 0.5938
# Counter: 28, Loss on training: 1.3397, Accuracy: 0.6406
# Counter: 29, Loss on training: 0.9952, Accuracy: 0.7188
# Counter: 30, Loss on training: 1.5242, Accuracy: 0.5625
# Counter: 31, Loss on training: 1.4981, Accuracy: 0.5781
# Counter: 32, Loss on training: 0.7790, Accuracy: 0.7812
# Counter: 33, Loss on training: 0.9769, Accuracy: 0.6875
# Counter: 34, Loss on training: 1.5495, Accuracy: 0.5000
# Counter: 35, Loss on training: 1.2457, Accuracy: 0.7812
# Counter: 36, Loss on training: 1.3043, Accuracy: 0.5312
# Counter: 37, Loss on training: 1.2309, Accuracy: 0.6562
# Counter: 38, Loss on training: 1.7101, Accuracy: 0.6094
# Counter: 39, Loss on training: 1.1272, Accuracy: 0.6406
# Counter: 40, Loss on training: 1.4484, Accuracy: 0.5469
# Counter: 41, Loss on training: 1.5264, Accuracy: 0.5625
# Counter: 42, Loss on training: 1.2490, Accuracy: 0.6562
# Counter: 43, Loss on training: 1.2336, Accuracy: 0.6406
# Counter: 44, Loss on training: 1.1102, Accuracy: 0.6719
# Counter: 45, Loss on training: 1.7476, Accuracy: 0.5781
# Counter: 46, Loss on training: 1.1137, Accuracy: 0.7031
# Counter: 47, Loss on training: 1.2790, Accuracy: 0.6562
# Counter: 48, Loss on training: 1.2659, Accuracy: 0.6562
# Counter: 49, Loss on training: 1.3975, Accuracy: 0.6719
# Counter: 50, Loss on training: 1.2543, Accuracy: 0.6719
# Counter: 51, Loss on training: 1.7536, Accuracy: 0.5781
# Counter: 52, Loss on training: 1.4688, Accuracy: 0.6250
# Counter: 53, Loss on training: 1.4233, Accuracy: 0.5938
# Counter: 54, Loss on training: 1.6082, Accuracy: 0.5469
# Counter: 55, Loss on training: 1.3834, Accuracy: 0.6562
# Counter: 56, Loss on training: 0.9758, Accuracy: 0.7344
# Counter: 57, Loss on training: 1.3055, Accuracy: 0.6094
# Counter: 58, Loss on training: 1.4132, Accuracy: 0.6250
# Counter: 59, Loss on training: 1.2298, Accuracy: 0.6562
# Counter: 60, Loss on training: 1.3541, Accuracy: 0.6250
# Counter: 61, Loss on training: 1.3489, Accuracy: 0.5781
# Counter: 62, Loss on training: 1.3787, Accuracy: 0.6719
# Counter: 63, Loss on training: 1.3286, Accuracy: 0.6406
# Counter: 64, Loss on training: 1.1232, Accuracy: 0.6250
# Counter: 65, Loss on training: 1.5538, Accuracy: 0.6094
# Counter: 66, Loss on training: 1.4060, Accuracy: 0.5781
# Counter: 67, Loss on training: 1.1389, Accuracy: 0.6719
# Counter: 68, Loss on training: 1.5168, Accuracy: 0.6562
# Counter: 69, Loss on training: 1.1640, Accuracy: 0.6406
# Counter: 70, Loss on training: 1.4252, Accuracy: 0.6094
# Counter: 71, Loss on training: 1.2118, Accuracy: 0.6719
# Counter: 72, Loss on training: 0.9899, Accuracy: 0.7188
# Counter: 73, Loss on training: 1.4124, Accuracy: 0.6250
# Counter: 74, Loss on training: 1.0481, Accuracy: 0.7344
# Counter: 75, Loss on training: 1.3623, Accuracy: 0.6875
# Counter: 76, Loss on training: 1.1149, Accuracy: 0.6406
# Counter: 77, Loss on training: 1.1528, Accuracy: 0.7031
# Counter: 78, Loss on training: 1.5952, Accuracy: 0.5469
# Counter: 79, Loss on training: 1.3533, Accuracy: 0.6094
# Counter: 80, Loss on training: 1.2402, Accuracy: 0.6562
# Counter: 81, Loss on training: 1.3533, Accuracy: 0.6719
# Counter: 82, Loss on training: 1.1385, Accuracy: 0.7031
# Counter: 83, Loss on training: 1.4534, Accuracy: 0.5938
# Counter: 84, Loss on training: 1.4299, Accuracy: 0.6406
# Counter: 85, Loss on training: 1.4140, Accuracy: 0.5938
# Counter: 86, Loss on training: 1.0615, Accuracy: 0.7188
# Counter: 87, Loss on training: 1.2038, Accuracy: 0.7188
# Counter: 88, Loss on training: 1.0910, Accuracy: 0.7031
# Counter: 89, Loss on training: 1.5198, Accuracy: 0.5625
# Counter: 90, Loss on training: 1.2450, Accuracy: 0.6875
# Counter: 91, Loss on training: 1.1952, Accuracy: 0.6406
# Counter: 92, Loss on training: 1.4740, Accuracy: 0.5781
# Counter: 93, Loss on training: 1.4277, Accuracy: 0.6406
# Counter: 94, Loss on training: 1.1523, Accuracy: 0.6406
# Counter: 95, Loss on training: 1.5879, Accuracy: 0.5625
# Counter: 96, Loss on training: 1.7995, Accuracy: 0.5156
# Counter: 97, Loss on training: 1.2295, Accuracy: 0.5781
# Counter: 98, Loss on training: 1.3960, Accuracy: 0.5938
# Counter: 99, Loss on training: 1.5102, Accuracy: 0.5938
# Counter: 100, Loss on training: 1.4039, Accuracy: 0.6094
# Counter: 101, Loss on training: 1.2471, Accuracy: 0.6094
# Counter: 102, Loss on training: 1.0178, Accuracy: 0.7083
# Epoch: 25/25
# Counter: 0, Loss on training: 1.2866, Accuracy: 0.6875
# Counter: 1, Loss on training: 0.9871, Accuracy: 0.7344
# Counter: 2, Loss on training: 1.1685, Accuracy: 0.6406
# Counter: 3, Loss on training: 1.7304, Accuracy: 0.6094
# Counter: 4, Loss on training: 1.1679, Accuracy: 0.6562
# Counter: 5, Loss on training: 1.2681, Accuracy: 0.6094
# Counter: 6, Loss on training: 1.1834, Accuracy: 0.7031
# Counter: 7, Loss on training: 1.3605, Accuracy: 0.5312
# Counter: 8, Loss on training: 1.4210, Accuracy: 0.6250
# Counter: 9, Loss on training: 0.9989, Accuracy: 0.7500
# Counter: 10, Loss on training: 1.3099, Accuracy: 0.6562
# Counter: 11, Loss on training: 0.9283, Accuracy: 0.6875
# Counter: 12, Loss on training: 1.4763, Accuracy: 0.6094
# Counter: 13, Loss on training: 1.2621, Accuracy: 0.5781
# Counter: 14, Loss on training: 1.3779, Accuracy: 0.5938
# Counter: 15, Loss on training: 1.4758, Accuracy: 0.5469
# Counter: 16, Loss on training: 1.0390, Accuracy: 0.7344
# Counter: 17, Loss on training: 1.2761, Accuracy: 0.6250
# Counter: 18, Loss on training: 1.2399, Accuracy: 0.6562
# Counter: 19, Loss on training: 1.1926, Accuracy: 0.6562
# Counter: 20, Loss on training: 1.3086, Accuracy: 0.6406
# Counter: 21, Loss on training: 0.9374, Accuracy: 0.7188
# Counter: 22, Loss on training: 1.1461, Accuracy: 0.6406
# Counter: 23, Loss on training: 1.2780, Accuracy: 0.6250
# Counter: 24, Loss on training: 1.1751, Accuracy: 0.6719
# Counter: 25, Loss on training: 1.2159, Accuracy: 0.5938
# Counter: 26, Loss on training: 0.9763, Accuracy: 0.6875
# Counter: 27, Loss on training: 1.3533, Accuracy: 0.6875
# Counter: 28, Loss on training: 1.2358, Accuracy: 0.6406
# Counter: 29, Loss on training: 1.5714, Accuracy: 0.5938
# Counter: 30, Loss on training: 1.1324, Accuracy: 0.7188
# Counter: 31, Loss on training: 1.2718, Accuracy: 0.5781
# Counter: 32, Loss on training: 1.2069, Accuracy: 0.6094
# Counter: 33, Loss on training: 1.3326, Accuracy: 0.5938
# Counter: 34, Loss on training: 1.3123, Accuracy: 0.6406
# Counter: 35, Loss on training: 0.8850, Accuracy: 0.7500
# Counter: 36, Loss on training: 1.3567, Accuracy: 0.5312
# Counter: 37, Loss on training: 1.1849, Accuracy: 0.6094
# Counter: 38, Loss on training: 1.3218, Accuracy: 0.6562
# Counter: 39, Loss on training: 0.9892, Accuracy: 0.6719
# Counter: 40, Loss on training: 1.2761, Accuracy: 0.6406
# Counter: 41, Loss on training: 1.1890, Accuracy: 0.6719
# Counter: 42, Loss on training: 1.2725, Accuracy: 0.6875
# Counter: 43, Loss on training: 1.3686, Accuracy: 0.5469
# Counter: 44, Loss on training: 1.3405, Accuracy: 0.6875
# Counter: 45, Loss on training: 1.3323, Accuracy: 0.6562
# Counter: 46, Loss on training: 1.2734, Accuracy: 0.6250
# Counter: 47, Loss on training: 0.9010, Accuracy: 0.7344
# Counter: 48, Loss on training: 1.3761, Accuracy: 0.6250
# Counter: 49, Loss on training: 1.4414, Accuracy: 0.5938
# Counter: 50, Loss on training: 1.3392, Accuracy: 0.6719
# Counter: 51, Loss on training: 1.3229, Accuracy: 0.5938
# Counter: 52, Loss on training: 1.0970, Accuracy: 0.7188
# Counter: 53, Loss on training: 1.3000, Accuracy: 0.6406
# Counter: 54, Loss on training: 1.2646, Accuracy: 0.6250
# Counter: 55, Loss on training: 1.5835, Accuracy: 0.5781
# Counter: 56, Loss on training: 1.4025, Accuracy: 0.6406
# Counter: 57, Loss on training: 1.0701, Accuracy: 0.6562
# Counter: 58, Loss on training: 1.4688, Accuracy: 0.6094
# Counter: 59, Loss on training: 1.2020, Accuracy: 0.7344
# Counter: 60, Loss on training: 1.2815, Accuracy: 0.7031
# Counter: 61, Loss on training: 1.3746, Accuracy: 0.6250
# Counter: 62, Loss on training: 1.4565, Accuracy: 0.6250
# Counter: 63, Loss on training: 1.2647, Accuracy: 0.6562
# Counter: 64, Loss on training: 1.6086, Accuracy: 0.5781
# Counter: 65, Loss on training: 1.3061, Accuracy: 0.5781
# Counter: 66, Loss on training: 1.4073, Accuracy: 0.5781
# Counter: 67, Loss on training: 1.2574, Accuracy: 0.6719
# Counter: 68, Loss on training: 1.3532, Accuracy: 0.7031
# Counter: 69, Loss on training: 1.2443, Accuracy: 0.5625
# Counter: 70, Loss on training: 1.1551, Accuracy: 0.7031
# Counter: 71, Loss on training: 1.2441, Accuracy: 0.6406
# Counter: 72, Loss on training: 1.4256, Accuracy: 0.5469
# Counter: 73, Loss on training: 1.5699, Accuracy: 0.6406
# Counter: 74, Loss on training: 1.4779, Accuracy: 0.5625
# Counter: 75, Loss on training: 1.2726, Accuracy: 0.6406
# Counter: 76, Loss on training: 1.0592, Accuracy: 0.7031
# Counter: 77, Loss on training: 1.2567, Accuracy: 0.5938
# Counter: 78, Loss on training: 1.8022, Accuracy: 0.5625
# Counter: 79, Loss on training: 1.6440, Accuracy: 0.5781
# Counter: 80, Loss on training: 1.5974, Accuracy: 0.5469
# Counter: 81, Loss on training: 1.0021, Accuracy: 0.7031
# Counter: 82, Loss on training: 1.1233, Accuracy: 0.7344
# Counter: 83, Loss on training: 1.3274, Accuracy: 0.5938
# Counter: 84, Loss on training: 1.4069, Accuracy: 0.6719
# Counter: 85, Loss on training: 1.3981, Accuracy: 0.5938
# Counter: 86, Loss on training: 1.2430, Accuracy: 0.6250
# Counter: 87, Loss on training: 1.3785, Accuracy: 0.6250
# Counter: 88, Loss on training: 1.4455, Accuracy: 0.6250
# Counter: 89, Loss on training: 1.6071, Accuracy: 0.5625
# Counter: 90, Loss on training: 1.1628, Accuracy: 0.6719
# Counter: 91, Loss on training: 1.0211, Accuracy: 0.6719
# Counter: 92, Loss on training: 1.7007, Accuracy: 0.5312
# Counter: 93, Loss on training: 1.6886, Accuracy: 0.5312
# Counter: 94, Loss on training: 1.4184, Accuracy: 0.5781
# Counter: 95, Loss on training: 1.5659, Accuracy: 0.6094
# Counter: 96, Loss on training: 1.0529, Accuracy: 0.7188
# Counter: 97, Loss on training: 1.2432, Accuracy: 0.6719
# Counter: 98, Loss on training: 1.5335, Accuracy: 0.5625
# Counter: 99, Loss on training: 0.9425, Accuracy: 0.7188
# Counter: 100, Loss on training: 1.3518, Accuracy: 0.5938
# Counter: 101, Loss on training: 1.0908, Accuracy: 0.7031
# Counter: 102, Loss on training: 1.7910, Accuracy: 0.5000

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
# Testing our model on unseen data
test_loss = 0
test_accuracy = 0
model.eval()           # To transfer the model to the evaluation mode
with torch.no_grad():
    for inputs, labels in testloader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')

        # logps = log probabilities
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)
        test_loss += batch_loss.item()

        # Calculate accuracy of test set
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        test_accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test loss: {test_loss/len(testloader):.3f}, "
      f"Test accuracy: {test_accuracy/len(testloader):.3f}")
running_loss = 0
# Out:
# Test loss: 0.644, Test accuracy: 0.826

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 

model.class_to_idx = train_data.class_to_idx
torch.save({'structure' :'vgg16',
            'hidden_layer1':120,
             'droupout':0.5,
             'epochs':12,
             'state_dict':model.state_dict(),
             'class_to_idx':model.class_to_idx,
             'optimizer_dict':optimizer.state_dict()},
             'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

# Here the function takes our saved file as input and rebuilds the model again 
def load_checkpoint(path='checkpoint.pth'):
    #load the saved file
    checkpoint = torch.load('checkpoint.pth')
    #download pretrained model
    model=models.vgg16(pretrained=True)
    #to freeze parameters
    for param in model.parameters():
        param.requires_grad = False
    #load from checkpoint
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    image = Image.open(image)
    
    #  Instead of doing it again we pass it to valid transforms to reduce repeatability
    return valid_transforms(image)
    # TODO: Process a PIL image for use in a PyTorch model

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
imshow(process_image('flowers/train/51/image_03966.jpg')) # Good Image XD

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model.eval()
    with torch.no_grad():
        logps = model.forward(process_image(image_path).unsqueeze(0))
        ps = torch.exp(logps)
        probs, labels = ps.topk(topk, dim=1)
        
        class_to_idx_inv = {model.class_to_idx[i]: i for i in model.class_to_idx}
        classes = list()
    
        for label in labels.numpy()[0]:
            classes.append(class_to_idx_inv[label])
        
        return probs.numpy()[0], classes
    # TODO: Implement the code to predict the class from an image file

# %%
model.cpu() # Because image on cpu 
probs, classes = predict('flowers/train/51/image_03966.jpg', model)
print(probs)
print(classes)
# Out:
# [ 0.59962016  0.11721371  0.05749114  0.05343114  0.03917876]
# ['51', '53', '30', '83', '72']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

# %%
flower_classes = [cat_to_name[j] for j in classes]

img = Image.open("flowers/test/51/image_01362.jpg")

plt.figure(figsize = [5, 10])
ax1 = plt.subplot(2, 1, 1)
ax1.set_axis_off()
ax1.set_title(flower_classes[0])
ax1.imshow(img)

ax2 = plt.subplot(2, 1, 2)
y_pos = np.arange(5)
ax2.set_yticks(y_pos)
ax2.set_yticklabels(flower_classes)
ax2.invert_yaxis()
ax2.set_xlabel('Probability')
plt.barh(y_pos, probs)
# Out:
# <Container object of 5 artists>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace

# %%
! rm *.pth
